# %% [markdown]
# <br>
#
# <center><img src='../Front_page/frontpage.png' style="width1:900px"></center>
#
# <br>
#
# <p style="font-size: 30px; text-align: center;"> <b>Session 0 - Introduction</b></p>
# <p style="font-size: 30px; text-align: center;"> <b>Excecise</b></p>
#
# ___

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font size="6"> &#127939;&#127997; </font>
# <b>Exercise: </b>
# <br>
# <br>
# Find any formula of your choice and program it in Jupyter Notebook. Here are the steps:
# <br>
# <br>
# First in the Markdown cells:
# <br>
# <br>
# • Include explanatory text enriched with multiple formatting options (bold, different sizes, etc.)<br>
# • Optionally, include your image or an image from the internet explaining the process or formula<br>
# • Optionally, for the bravest, include a flowchart using Mermaid
#
# <br>
# <br>
#
# In the code cells:
#
# • Load the necessary libraries<br>
# • Generate the input data (x or independent variable)<br>
# • Calculate the output data (y or dependent variable) with your formula, which may include a constant (for example, g = 9.8 m/s2)<br>
# • Graph x versus y<br>
#
# </div>
